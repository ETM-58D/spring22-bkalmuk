# %% [markdown]
# ## Burçak Aysen Kalmuk HW3

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def prepare_data(path, ax):
    df = pd.read_csv(path, sep = '\s+', header = None)
    columns = [ax + 'T' + str(i) for i in range(1, df.shape[1])]
    columns.insert(0, 'class')
    df.columns = columns
    df['class'] = df['class'].astype(int)
    return df

# %%
x_train = prepare_data("uWaveGestureLibrary_X_TRAIN", "X")
y_train = prepare_data("uWaveGestureLibrary_Y_TRAIN", "Y")
z_train = prepare_data("uWaveGestureLibrary_Z_TRAIN", "Z")

# %%
x_train.head()
# Out:
#    class       XT1       XT2       XT3       XT4       XT5       XT6  \
# 0      6 -0.304243 -0.304243 -0.304243 -0.304243 -0.304243 -0.304243
# 1      5  1.627311  1.627311  1.627311  1.627311  1.627311  1.627311
# 2      5  0.661277  0.661277  0.661277  0.661277  0.661277  0.661277
# 3      3  0.005185  0.005185  0.005185  0.005185  0.005185  0.005185
# 4      4  1.286198  1.286198  1.286198  1.286198  1.286198  1.286198
#
#         XT7       XT8       XT9  ...     XT306     XT307     XT308     XT309  \
# 0 -0.304243 -0.304243 -0.304243  ... -0.796414 -0.741728 -0.694698 -0.647669
# 1  1.627311  1.627311  1.627311  ... -0.237634 -0.237634 -0.237634 -0.237634
# 2  0.661277  0.661277  0.661277  ... -0.282011 -0.236929 -0.191848 -0.146766
# 3  0.005185  0.005185  0.005185  ...  1.207290  1.147822  1.094344  1.060362
# 4  1.286198  1.286198  1.286198  ... -1.436983 -1.436983 -1.436983 -1.436983
#
#       XT310     XT311     XT312     XT313     XT314     XT315
# ...

# %%
y_train.head()
# Out:
#    class       YT1       YT2       YT3       YT4       YT5       YT6  \
# 0      6 -2.119396 -2.119396 -2.119396 -2.119396 -2.119396 -2.119396
# 1      5  0.666624  0.666624  0.666624  0.666624  0.666624  0.666624
# 2      5 -0.189730 -0.189730 -0.189730 -0.189730 -0.189730 -0.189730
# 3      3  0.374067  0.374067  0.374067  0.374067  0.374067  0.374067
# 4      4 -0.397437 -0.397437 -0.397437 -0.397437 -0.397437 -0.397437
#
#         YT7       YT8       YT9  ...     YT306     YT307     YT308     YT309  \
# 0 -2.119396 -2.119396 -2.119396  ...  0.084123  0.084123  0.084123  0.084123
# 1  0.666624  0.666624  0.666624  ... -1.517261 -1.554968 -1.592674 -1.629870
# 2 -0.189730 -0.189730 -0.189730  ... -1.492490 -1.492490 -1.492490 -1.492490
# 3  0.374067  0.374067  0.374067  ... -1.531698 -1.639404 -1.747843 -1.837563
# 4 -0.397437 -0.397437 -0.397437  ... -2.180807 -2.222432 -2.241745 -2.241745
#
#       YT310     YT311     YT312     YT313     YT314     YT315
# ...

# %%
z_train.head()
# Out:
#    class       ZT1       ZT2       ZT3       ZT4       ZT5       ZT6  \
# 0      6 -1.528965 -1.528965 -1.528965 -1.528965 -1.528965 -1.528965
# 1      5  1.786869  1.786869  1.786869  1.786869  1.786869  1.786869
# 2      5  0.521249  0.521249  0.521249  0.521249  0.521249  0.521249
# 3      3  0.309455  0.309455  0.309455  0.309455  0.309455  0.309455
# 4      4 -0.466022 -0.466022 -0.466022 -0.466022 -0.466022 -0.466022
#
#         ZT7       ZT8       ZT9  ...     ZT306     ZT307     ZT308     ZT309  \
# 0 -1.528965 -1.528965 -1.528965  ...  0.523217  0.513994  0.503481  0.492967
# 1  1.786869  1.786869  1.786869  ... -0.427010 -0.427010 -0.427010 -0.427172
# 2  0.521249  0.521249  0.521249  ... -0.862717 -0.862717 -0.862717 -0.862717
# 3  0.309455  0.309455  0.309455  ... -0.187384 -0.123549 -0.055870  0.011808
# 4 -0.466022 -0.466022 -0.466022  ...  1.867473  1.834319  1.756000  1.638582
#
#       ZT310     ZT311     ZT312     ZT313     ZT314     ZT315
# ...

# %%
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")

x_row2 = x_train.iloc[[2]]
y_row2 = y_train.iloc[[2]]
z_row2 = z_train.iloc[[2]]

# Creating plot
ax.scatter3D(x_row2, y_row2, z_row2, color = "green")
plt.title("3D scatter plot")
plt.show()

# %%
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")

x_row5 = x_train.iloc[[5]]
y_row5 = y_train.iloc[[5]]
z_row5 = z_train.iloc[[5]]

# Creating plot
ax.scatter3D(x_row5, y_row5, z_row5, color = "green")
plt.title("3D scatter plot")
plt.show()
